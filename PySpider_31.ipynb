# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
#import pytesseract
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %%
img1 = plt.imread('C:/Users/hsu/Desktop/test1.png')
plt.imshow(img1)

# %%
img2 = plt.imread('C:/Users/hsu/Desktop/test2.png')
plt.imshow(img2)

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
img = Image.open("test/test2.png").convert("L")
img
# Out:
# <PIL.Image.Image image mode=L size=154x64 at 0x10F37E240>

# %%
# 運用深度學習的圖片辨識，進行資料解析
# Out:
# '\nYour Code\n'
