# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
from pyquery import PyQuery as pq
from grab import Grab

# %%
URL = 'https://news.pts.org.tw/dailynews.php'
resp = requests.get(url=URL)
soup = BeautifulSoup(markup=resp.text, features='html.parser')
nodes = soup.select(selector = 'h2')
for i in nodes:
    print(i.text)
# Out:
# 強化醫療資源調度 指揮中心不分縣市設檢疫所後送醫院「綠色通道」
# 北市仍有31確診者失聯 柯下令快篩陽性者PCR優先送檢阻斷傳播
# 侯：新北八成確診者有萬華接觸活動史 感染源未清除28日解除三級不樂觀
# 皆無罩！醉男餐廳咳嗽咆哮、高雄民宅9人群聚打麻將
# 刑事局偵查佐PCR採檢陽性 高院法警快篩陽性安置隔離
# 西螺確診父子交遊廣足跡遍佈全鎮 雲縣啟動西螺社區快篩站
# 昨8例確診有7例在潮州鎮 國軍化學兵支援屏縣府全潮州大消毒
# 高鐵證實一車安保全快篩陽性 14日曾接獲通知服勤列車有確診者
# 供電吃緊 台電大林廠、中火9號機接連故障搶修
# 「維珍銀河」載人太空飛行成功 稱最快明年啟動太空觀光
# 指揮中心撤銷金門快篩令 縣長楊鎮浯稱曾二度發函中央未獲回應
# 基隆市府公布2確診者足跡 林右昌建議三級警戒再延2週
# 運輸倉儲、旅行業無薪假嚴重 立委提議政府補貼因防疫照顧假衝擊生計家庭
# 24日6例染疫死亡創單日新高 醫師：中高齡、慢性病確診者變多
# 台股早盤因疫挫 傳產盤中奮起一度紅

# %% [markdown]
# ## Grab + PyQuery

# %%
g = Grab()
resp = g.go(URL)
resp.body
# Out:
# b'<!DOCTYPE html>\n<html lang="">\n<head>\n    <meta charset="UTF-8">\n    \n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n    <link href="/favicon.ico" rel="icon" type="image/x-icon">\n\n    <!-- Google Tag Manager -->\n    <script>(function (w, d, s, l, i) {\n            w[l] = w[l] || [];\n            w[l].push({\n                \'gtm.start\':\n                    new Date().getTime(), event: \'gtm.js\'\n            });\n            var f = d.getElementsByTagName(s)[0],\n                j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n            j.async = true;\n            j.src =\n                \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n            f.parentNode.insertBefore(j, f);\n        })(window, document, \'script\', \'dataLayer\', \'GTM-W3W2ZR4\');</script>\n    <!-- End Google Tag Manager -->\n\n    <!-- Begin comScore Tag -->\n    <script>\n        var _comscore = _comscore || [];\n        _comscore.push({c1: "2", c2: "26875971"});\n        (function () {\n            var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\n            s.async = true;\n            s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";\n            el.parentNode.insertBefore(s, el);\n        })();\n    </script>\n    <noscript>\n        <img src="https://sb.scorecardresearch.com/p?c1=2&c2=26875971&cv=2.0&cj=1"/>\n    </noscript>\n\n    <!-- Begin LnData Tag -->\n    <script type="text/javascript">\n        var _smq = _smq || [];\n\n        _smq.push([\'_setAccount\', \'42bcc0b\', new Date()]);\n        _smq.push([\'_setDomainName\', \'pts.org.tw\']);\n        _smq.push([\'pageview\']);\n\n        (function () {\n            var sm = document.createElement(\'script\');\n            sm.type = \'text/javascript\';\n            sm.async = true;\n            sm.src = (\'https:\' == document.location.protocol ? \'https://\' : \'http://\') + \'cdn.lndata.com/collect.js\';\n            var s = document.getElementsByTagName(\'script\')[0];\n            s.parentNode.insertBefore(sm, s);\n        })();\n    </script>\n\n    <!-- MINIFIED -->\n\n    <title>\xe5\x8d\xb3\xe6\x99\x82 \xef\xbd\x9c \xe5\x85\xac\xe8\xa6\x96\xe6\x96\xb0\xe8\x81\x9e\xe7\xb6\xb2 PNN</title>\n<meta name="description" content="">\n<meta property="article:published_time" content="2021-05-24T12:56:09+08:00">\n<link rel="canonical" href="https://news.pts.org.tw/dailynews"/>\n<meta property="og:title" content="\xe5\x8d\xb3\xe6\x99\x82 \xef\xbd\x9c \xe5\x85\xac\xe8\xa6\x96\xe6\x96\xb0\xe8\x81\x9e\xe7\xb6\xb2 PNN" />\n<meta property="og:description" content="\xe ...

# %%
doc = pq(resp.body)
title = doc('h2')
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> 強化醫療資源調度 指揮中心不分縣市設檢疫所後送醫院「綠色通道」 北市仍有31確診者失聯 柯下令快篩陽性者PCR優先送檢阻斷傳播 侯：新北八成確診者有萬華接觸活動史 感染源未清除28日解除三級不樂觀 皆無罩！醉男餐廳咳嗽咆哮、高雄民宅9人群聚打麻將 刑事局偵查佐PCR採檢陽性 高院法警快篩陽性安置隔離 西螺確診父子交遊廣足跡遍佈全鎮 雲縣啟動西螺社區快篩站 昨8例確診有7例在潮州鎮 國軍化學兵支援屏縣府全潮州大消毒 高鐵證實一車安保全快篩陽性 14日曾接獲通知服勤列車有確診者 供電吃緊 台電大林廠、中火9號機接連故障搶修 「維珍銀河」載人太空飛行成功 稱最快明年啟動太空觀光 指揮中心撤銷金門快篩令 縣長楊鎮浯稱曾二度發函中央未獲回應 基隆市府公布2確診者足跡 林右昌建議三級警戒再延2週 運輸倉儲、旅行業無薪假嚴重 立委提議政府補貼因防疫照顧假衝擊生計家庭 24日6例染疫死亡創單日新高 醫師：中高齡、慢性病確診者變多 台股早盤因疫挫 傳產盤中奮起一度紅
