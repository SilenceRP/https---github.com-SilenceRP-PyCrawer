# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"16470364575","type":"PushEvent","actor":{"id":46893889,"login":"appexplore","display_login":"appexplore","gravatar_id":"","url":"https://api.github.com/users/appexplore","avatar_url":"https://avatars.githubusercontent.com/u/46893889?"},"repo":{"id":339922209,"name":"appexplore/check","url":"https://api.github.com/repos/appexplore/check"},"payload":{"push_id":7172327208,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"de1a0f62e28f421a0c7e1e742dd1bdba852a91b7","before":"cf6281925f4a7fe1bc81befeac99f94697719844","commits":[{"sha":"e65447b88776b4d57f46eec7f45ebfe5194fc972","author":{"email":"73812536+upptime-bot@users.noreply.github.com","name":"Upptime Bot"},"message":"\U0001f7e5 软件探索首页 is down (0 in 0 ms) [skip ci] [upptime]","distinct":true,"url":"https://api.github.com/repos/appexplore/check/commits/e65447b88776b4d57f46eec7f45ebfe5194fc972"},{"sha":"de1a0f62e28f421a0c7e1e742dd1bdba852a91b7","author":{"email":"73812536+upptime-bot@users.noreply.github.com","name":"Upptime Bot"},"message":"\U0001f7e9 简约导航 is up (200 in 821 ms) [skip ci] [upptime]","distinct":true,"url":"https://api.github.com/repos/appexplore/check/commits/de1a0f62e28f421a0c7e1e742dd1bdba852a91b7"}]},"public":true,"created_at":"2021-05-23T09:31:13Z"},{"id":"16470364569","type":"PushEvent","actor":{"id":18567580,"login":"conda-forge-linter","display_login":"conda-forge-linter","gravatar_id":"","url":"https://api.github.com/users/conda-forge-linter","avatar_url":"https://avatars.githubusercontent.com/u/18567580?"},"repo":{"id":237681259,"name":"conda-forge/conda-forge-status-monitor","url":"https://api.github.com/repos/conda-forge/conda-forge-status-monitor"},"payload":{"push_id":7172327201,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"aba0d6b438d84dca164faae0e5a9b3346781e8f2","before":"20075038992c09411ce0cd2d4760b7da1f252563","commits":[{"sha":"aba0d6b438d84dca164faae0e5a9b3346781e8f2","author":{"email":"pelson.pub+conda-forge@gmail.com","name":"conda-forge-admin"},"message":"[ci skip] [skip ci] [cf admin skip] ***NO_CI*** status data update 2021-05-23T09:31:10.996209","distinct":true,"url":"https://api.github.com/repos/conda-forge/conda-forge-status-monitor/commits/aba0d6b438d84dca164faae0e5a9b3346781e8f2"}]},"public":true,"created_at":"2021-05-23T09:31:13Z","org":{"id":11897326,"login":"conda-forge","gravatar_id":"","url":"https://api.github.com/orgs/conda-forge","avatar_url":"https://avatars.githubusercontent.com/u/11897326?"}},{"id":"16470364572","type":"IssueCommentEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":19358114,"name":"night/betterttv","url":"https://api.github.com/repos/night/betterttv"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/night/betterttv/issues/1780","repository_url":"https://api.github.com/repos/night/betterttv","labels_url":"https://api.github.com/repos/night/betterttv/issues/1780/labels{/name}","comments_url":"https://api.github.com/repos/night/betterttv/issues/1780/comments","events_url":"https://api.github.com/repos/night/betterttv/issues/1780/events","html_url":"https://github.com/night/betterttv/pull/1780","id":190619980,"node_id":"MDExOlB1bGxSZXF1ZXN0OTQ1NTQ5MjI=","number":1780,"title":"Fix icon alignment and fullscreen issues","user":{"login":"EhsanKia","id":1619970,"node_id":"MDQ6VXNlcjE2MTk5NzA=","avatar_url":"https://avatars.githubusercontent.com/u/1619970?v=4","gravatar_id":"","url":"https://api.github.com/users/EhsanKia","html_url":"https://github.com/EhsanKia","followers_url":"https://api.github.com/users/EhsanKia/followers","following_url":"https://api.github.com/users/EhsanKia/following{/other_user}","gists_url":"https://api.github.com/users/EhsanKia/gists{/gist_id}","starred_url":"https://api.github.com/users/EhsanKia/starred{/owner}{/repo}","subscriptions_url ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '16470364575',
#   'type': 'PushEvent',
#   'actor': {'id': 46893889,
#    'login': 'appexplore',
#    'display_login': 'appexplore',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/appexplore',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46893889?'},
#   'repo': {'id': 339922209,
#    'name': 'appexplore/check',
#    'url': 'https://api.github.com/repos/appexplore/check'},
#   'payload': {'push_id': 7172327208,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'de1a0f62e28f421a0c7e1e742dd1bdba852a91b7',
#    'before': 'cf6281925f4a7fe1bc81befeac99f94697719844',
#    'commits': [{'sha': 'e65447b88776b4d57f46eec7f45ebfe5194fc972',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e5 软件探索首页 is down (0 in 0 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/appexplore/check/commits/e65447b88776b4d57f46eec7f45ebfe5194fc972'},
#     {'sha': 'de1a0f62e28f421a0c7e1e742dd1bdba852a91b7',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '\U0001f7e9 简约导航 is up (200 in 821 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/appexplore/check/commits/de1a0f62e28f421a0c7e1e742dd1bdba852a91b7'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364569',
#   'type': 'PushEvent',
#   'actor': {'id': 18567580,
#    'login': 'conda-forge-linter',
#    'display_login': 'conda-forge-linter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/conda-forge-linter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18567580?'},
#   'repo': {'id': 237681259,
#    'name': 'conda-forge/conda-forge-status-monitor',
#    'url': 'https://api.github.com/repos/conda-forge/conda-forge-status-monitor'},
#   'payload': {'push_id': 7172327201,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'aba0d6b438d84dca164faae0e5a9b3346781e8f2',
#    'before': '20075038992c09411ce0cd2d4760b7da1f252563',
#    'commits': [{'sha': 'aba0d6b438d84dca164faae0e5a9b3346781e8f2',
#      'author': {'email': 'pelson.pub+conda-forge@gmail.com',
#       'name': 'conda-forge-admin'},
#      'message': '[ci skip] [skip ci] [cf admin skip] ***NO_CI*** status data update 2021-05-23T09:31:10.996209',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/conda-forge/conda-forge-status-monitor/commits/aba0d6b438d84dca164faae0e5a9b3346781e8f2'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z',
#   'org': {'id': 11897326,
#    'login': 'conda-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/conda-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?'}},
#  {'id': '16470364572',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 19358114,
#    'name': 'night/betterttv',
#    'url': 'https://api.github.com/repos/night/betterttv'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/night/betterttv/issues/1780',
#     'repository_url': 'https://api.github.com/repos/night/betterttv',
#     'labels_url': 'https://api.github.com/repos/night/betterttv/issues/1780/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/night/betterttv/issues/1780/comments',
#     'events_url': 'https://api.github.com/repos/night/betterttv/issues/1780/events',
#     'html_url': 'https://github.com/night/betterttv/pull/1780',
#     'id': 190619980,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0OTQ1NTQ5MjI=',
#     'number': 1780,
#     'title': 'Fix icon alignment and fullscreen issues',
#     'user': {'login': 'EhsanKia',
#      'id': 1619970,
#      'node_id': 'MDQ6VXNlcjE2MTk5NzA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1619970?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/EhsanKia',
#      'html_url': 'https://github.com/EhsanKia',
#      'followers_url': 'https://api.github.com/users/EhsanKia/followers',
#      'following_url': 'https://api.github.com/users/EhsanKia/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/EhsanKia/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/EhsanKia/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/EhsanKia/subscriptions',
#      'organizations_url': 'https://api.github.com/users/EhsanKia/orgs',
#      'repos_url': 'https://api.github.com/users/EhsanKia/repos',
#      'events_url': 'https://api.github.com/users/EhsanKia/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/EhsanKia/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2016-11-21T05:04:30Z',
#     'updated_at': '2021-05-23T09:31:13Z',
#     'closed_at': '2016-11-22T03:12:07Z',
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/night/betterttv/pulls/1780',
#      'html_url': 'https://github.com/night/betterttv/pull/1780',
#      'diff_url': 'https://github.com/night/betterttv/pull/1780.diff',
#      'patch_url': 'https://github.com/night/betterttv/pull/1780.patch'},
#     'body': "This should fix the icon alignment in #1777 \r\n\r\nIt'll also force the window to scroll up when you leave fullscreen fixing #1771 \r\n\r\nI think I also found the issue with #1772 , it seems like a jquery bug with .data(), it caches the results and doesn't update when they change...",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/night/betterttv/issues/comments/846532871',
#     'html_url': 'https://github.com/night/betterttv/pull/1780#issuecomment-846532871',
#     'issue_url': 'https://api.github.com/repos/night/betterttv/issues/1780',
#     'id': 846532871,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDg0NjUzMjg3MQ==',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-05-23T09:31:13Z',
#     'updated_at': '2021-05-23T09:31:13Z',
#     'author_association': 'NONE',
#     'body': 'This pull request has been automatically locked since there has not been any recent activity after it was closed. Please open a new pull request for related issues or feature requests.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364577',
#   'type': 'CreateEvent',
#   'actor': {'id': 83754074,
#    'login': 'imonmahamud',
#    'display_login': 'imonmahamud',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/imonmahamud',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83754074?'},
#   'repo': {'id': 369998042,
#    'name': 'imonmahamud/mixin-in-JS',
#    'url': 'https://api.github.com/repos/imonmahamud/mixin-in-JS'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364573',
#   'type': 'CreateEvent',
#   'actor': {'id': 40390406,
#    'login': 'moyoyomiyazawa',
#    'display_login': 'moyoyomiyazawa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moyoyomiyazawa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40390406?'},
#   'repo': {'id': 370011086,
#    'name': 'moyoyomiyazawa/facebook-clone-nextjs',
#    'url': 'https://api.github.com/repos/moyoyomiyazawa/facebook-clone-nextjs'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364566',
#   'type': 'CreateEvent',
#   'actor': {'id': 79913779,
#    'login': 'conda-forge-curator[bot]',
#    'display_login': 'conda-forge-curator',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/conda-forge-curator[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79913779?'},
#   'repo': {'id': 288431736,
#    'name': 'conda-forge/releases',
#    'url': 'https://api.github.com/repos/conda-forge/releases'},
#   'payload': {'ref': 'osx-64/r-protviz-0.6.8-r40h9951f98_1.tar.bz2',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'releases of conda-forge builds',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z',
#   'org': {'id': 11897326,
#    'login': 'conda-forge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/conda-forge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11897326?'}},
#  {'id': '16470364559',
#   'type': 'PushEvent',
#   'actor': {'id': 38742004,
#    'login': 'brussliu',
#    'display_login': 'brussliu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brussliu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38742004?'},
#   'repo': {'id': 239185696,
#    'name': 'brussliu/smartinfo',
#    'url': 'https://api.github.com/repos/brussliu/smartinfo'},
#   'payload': {'push_id': 7172327198,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '77823e14df38eee786309824f753d442c287d64e',
#    'before': '84498652277aa18f1032e2abb90df40a08075cb2',
#    'commits': [{'sha': '77823e14df38eee786309824f753d442c287d64e',
#      'author': {'email': 'bruss.ji.liu@gmail.com', 'name': 'brussliu'},
#      'message': 'sdfs\n\nsfssf',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brussliu/smartinfo/commits/77823e14df38eee786309824f753d442c287d64e'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364555',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 16105680,
#    'login': 'nikhita',
#    'display_login': 'nikhita',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nikhita',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16105680?'},
#   'repo': {'id': 20580498,
#    'name': 'kubernetes/kubernetes',
#    'url': 'https://api.github.com/repos/kubernetes/kubernetes'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/96130',
#     'repository_url': 'https://api.github.com/repos/kubernetes/kubernetes',
#     'labels_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/96130/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/96130/comments',
#     'events_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/96130/events',
#     'html_url': 'https://github.com/kubernetes/kubernetes/pull/96130',
#     'id': 734918624,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTE0NDAxMTY1',
#     'number': 96130,
#     'title': 'Removing utils/mount dependencies from vendor',
#     'user': {'login': 'brahmaroutu',
#      'id': 5403596,
#      'node_id': 'MDQ6VXNlcjU0MDM1OTY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/5403596?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/brahmaroutu',
#      'html_url': 'https://github.com/brahmaroutu',
#      'followers_url': 'https://api.github.com/users/brahmaroutu/followers',
#      'following_url': 'https://api.github.com/users/brahmaroutu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/brahmaroutu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/brahmaroutu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/brahmaroutu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/brahmaroutu/orgs',
#      'repos_url': 'https://api.github.com/users/brahmaroutu/repos',
#      'events_url': 'https://api.github.com/users/brahmaroutu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/brahmaroutu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 414883982,
#       'node_id': 'MDU6TGFiZWw0MTQ4ODM5ODI=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/approved',
#       'name': 'approved',
#       'color': '0ffa16',
#       'default': False,
#       'description': 'Indicates a PR has been approved by an approver from all required OWNERS files.'},
#      {'id': 154660912,
#       'node_id': 'MDU6TGFiZWwxNTQ2NjA5MTI=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/area/cloudprovider',
#       'name': 'area/cloudprovider',
#       'color': '0052cc',
#       'default': False,
#       'description': None},
#      {'id': 268190668,
#       'node_id': 'MDU6TGFiZWwyNjgxOTA2Njg=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/area/release-eng',
#       'name': 'area/release-eng',
#       'color': '0052cc',
#       'default': False,
#       'description': 'Issues or PRs related to the Release Engineering subproject'},
#      {'id': 477397086,
#       'node_id': 'MDU6TGFiZWw0NzczOTcwODY=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/cncf-cla:%20yes',
#       'name': 'cncf-cla: yes',
#       'color': 'bfe5bf',
#       'default': False,
#       'description': "Indicates the PR's author has signed the CNCF CLA."},
#      {'id': 687565804,
#       'node_id': 'MDU6TGFiZWw2ODc1NjU4MDQ=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/do-not-merge/hold',
#       'name': 'do-not-merge/hold',
#       'color': 'e11d21',
#       'default': False,
#       'description': 'Indicates that a PR should not merge because someone has issued a /hold command.'},
#      {'id': 122775691,
#       'node_id': 'MDU6TGFiZWwxMjI3NzU2OTE=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/kind/cleanup',
#       'name': 'kind/cleanup',
#       'color': 'c7def8',
#       'default': False,
#       'description': 'Categorizes issue or PR as related to cleaning up code, process, or technical debt.'},
#      {'id': 148225179,
#       'node_id': 'MDU6TGFiZWwxNDgyMjUxNzk=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/lgtm',
#       'name': 'lgtm',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates that a PR is ready to be merged.'},
#      {'id': 1111992057,
#       'node_id': 'MDU6TGFiZWwxMTExOTkyMDU3',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/needs-priority',
#       'name': 'needs-priority',
#       'color': 'ededed',
#       'default': False,
#       'description': 'Indicates a PR lacks a `priority/foo` label and requires one.'},
#      {'id': 349530249,
#       'node_id': 'MDU6TGFiZWwzNDk1MzAyNDk=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/release-note-none',
#       'name': 'release-note-none',
#       'color': 'c2e0c6',
#       'default': False,
#       'description': "Denotes a PR that doesn't merit a release note."},
#      {'id': 958178286,
#       'node_id': 'MDU6TGFiZWw5NTgxNzgyODY=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/sig/cloud-provider',
#       'name': 'sig/cloud-provider',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to SIG Cloud Provider.'},
#      {'id': 614023989,
#       'node_id': 'MDU6TGFiZWw2MTQwMjM5ODk=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/sig/release',
#       'name': 'sig/release',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to SIG Release.'},
#      {'id': 169428334,
#       'node_id': 'MDU6TGFiZWwxNjk0MjgzMzQ=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/sig/storage',
#       'name': 'sig/storage',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to SIG Storage.'},
#      {'id': 253450934,
#       'node_id': 'MDU6TGFiZWwyNTM0NTA5MzQ=',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/size/M',
#       'name': 'size/M',
#       'color': 'eebb00',
#       'default': False,
#       'description': 'Denotes a PR that changes 30-99 lines, ignoring generated files.'},
#      {'id': 2389856656,
#       'node_id': 'MDU6TGFiZWwyMzg5ODU2NjU2',
#       'url': 'https://api.github.com/repos/kubernetes/kubernetes/labels/triage/accepted',
#       'name': 'triage/accepted',
#       'color': '8fc951',
#       'default': False,
#       'description': 'Indicates an issue or PR is ready to be actively worked on.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'dims',
#      'id': 23304,
#      'node_id': 'MDQ6VXNlcjIzMzA0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/23304?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dims',
#      'html_url': 'https://github.com/dims',
#      'followers_url': 'https://api.github.com/users/dims/followers',
#      'following_url': 'https://api.github.com/users/dims/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dims/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dims/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dims/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dims/orgs',
#      'repos_url': 'https://api.github.com/users/dims/repos',
#      'events_url': 'https://api.github.com/users/dims/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dims/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'dims',
#       'id': 23304,
#       'node_id': 'MDQ6VXNlcjIzMzA0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/23304?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dims',
#       'html_url': 'https://github.com/dims',
#       'followers_url': 'https://api.github.com/users/dims/followers',
#       'following_url': 'https://api.github.com/users/dims/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dims/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dims/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dims/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dims/orgs',
#       'repos_url': 'https://api.github.com/users/dims/repos',
#       'events_url': 'https://api.github.com/users/dims/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dims/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'thockin',
#       'id': 5595220,
#       'node_id': 'MDQ6VXNlcjU1OTUyMjA=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/5595220?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/thockin',
#       'html_url': 'https://github.com/thockin',
#       'followers_url': 'https://api.github.com/users/thockin/followers',
#       'following_url': 'https://api.github.com/users/thockin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/thockin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/thockin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/thockin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/thockin/orgs',
#       'repos_url': 'https://api.github.com/users/thockin/repos',
#       'events_url': 'https://api.github.com/users/thockin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/thockin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'nikhita',
#       'id': 16105680,
#       'node_id': 'MDQ6VXNlcjE2MTA1Njgw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/16105680?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nikhita',
#       'html_url': 'https://github.com/nikhita',
#       'followers_url': 'https://api.github.com/users/nikhita/followers',
#       'following_url': 'https://api.github.com/users/nikhita/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nikhita/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nikhita/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nikhita/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nikhita/orgs',
#       'repos_url': 'https://api.github.com/users/nikhita/repos',
#       'events_url': 'https://api.github.com/users/nikhita/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nikhita/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'msau42',
#       'id': 24448061,
#       'node_id': 'MDQ6VXNlcjI0NDQ4MDYx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/24448061?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/msau42',
#       'html_url': 'https://github.com/msau42',
#       'followers_url': 'https://api.github.com/users/msau42/followers',
#       'following_url': 'https://api.github.com/users/msau42/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/msau42/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/msau42/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/msau42/subscriptions',
#       'organizations_url': 'https://api.github.com/users/msau42/orgs',
#       'repos_url': 'https://api.github.com/users/msau42/repos',
#       'events_url': 'https://api.github.com/users/msau42/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/msau42/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 16,
#     'created_at': '2020-11-03T00:00:23Z',
#     'updated_at': '2021-05-23T09:31:13Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/pulls/96130',
#      'html_url': 'https://github.com/kubernetes/kubernetes/pull/96130',
#      'diff_url': 'https://github.com/kubernetes/kubernetes/pull/96130.diff',
#      'patch_url': 'https://github.com/kubernetes/kubernetes/pull/96130.patch'},
#     'body': '/kind cleanup\r\n\r\nThis PR will cleanup third-party dependencies on vendored utils/mount and finally all the code uses the new mount-utils under staging. This is part of the effort made under \r\nhttps://github.com/kubernetes/enhancements/pull/1760\r\nrefs: https://github.com/kubernetes/org/issues/1887, https://github.com/kubernetes/kubernetes/pull/91596 and https://github.com/kubernetes/kubernetes/pull/94527\r\n\r\nFinally cAdvisor code changed to use the new repo : https://github.com/google/cadvisor/pull/2687\r\nWe need the new cAdvisor code to be vendored to pick up the PR#2687 mentioned above\r\ngithub.com/google/cadvisor v0.37.0  => github.com/google/cadvisor v0.38.0 \r\nHold this PR until advisor code is updated. @bobbypage \r\n/hold \r\n/release-note-none\r\n/sig storage\r\n\r\nping @msau42 \r\n\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/comments/846532870',
#     'html_url': 'https://github.com/kubernetes/kubernetes/pull/96130#issuecomment-846532870',
#     'issue_url': 'https://api.github.com/repos/kubernetes/kubernetes/issues/96130',
#     'id': 846532870,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDg0NjUzMjg3MA==',
#     'user': {'login': 'nikhita',
#      'id': 16105680,
#      'node_id': 'MDQ6VXNlcjE2MTA1Njgw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16105680?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nikhita',
#      'html_url': 'https://github.com/nikhita',
#      'followers_url': 'https://api.github.com/users/nikhita/followers',
#      'following_url': 'https://api.github.com/users/nikhita/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nikhita/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nikhita/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nikhita/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nikhita/orgs',
#      'repos_url': 'https://api.github.com/users/nikhita/repos',
#      'events_url': 'https://api.github.com/users/nikhita/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nikhita/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-05-23T09:31:13Z',
#     'updated_at': '2021-05-23T09:31:13Z',
#     'author_association': 'MEMBER',
#     'body': '@brahmaroutu please cancel the hold when ready',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z',
#   'org': {'id': 13629408,
#    'login': 'kubernetes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubernetes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13629408?'}},
#  {'id': '16470364564',
#   'type': 'PushEvent',
#   'actor': {'id': 3581271,
#    'login': 'vasyakrg',
#    'display_login': 'vasyakrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vasyakrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3581271?'},
#   'repo': {'id': 369066024,
#    'name': 'vasyakrg/Kubernetes-deploy',
#    'url': 'https://api.github.com/repos/vasyakrg/Kubernetes-deploy'},
#   'payload': {'push_id': 7172327199,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '872c9c1b4e83d82d2562e3cd88d684e1685660c2',
#    'before': 'bc234edfeaff9aab255b91a8114514fe9e205a28',
#    'commits': [{'sha': '872c9c1b4e83d82d2562e3cd88d684e1685660c2',
#      'author': {'email': 'vasyakrg@gmail.com', 'name': 'Vassiliy Yegorov'},
#      'message': 'fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vasyakrg/Kubernetes-deploy/commits/872c9c1b4e83d82d2562e3cd88d684e1685660c2'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364558',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 66245404,
#    'login': 'tovade',
#    'display_login': 'tovade',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tovade',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?'},
#   'repo': {'id': 290533649,
#    'name': 'tovade/Andoi',
#    'url': 'https://api.github.com/repos/tovade/Andoi'},
#   'payload': {'action': 'opened',
#    'number': 9,
#    'pull_request': {'url': 'https://api.github.com/repos/tovade/Andoi/pulls/9',
#     'id': 650756704,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjUwNzU2NzA0',
#     'html_url': 'https://github.com/tovade/Andoi/pull/9',
#     'diff_url': 'https://github.com/tovade/Andoi/pull/9.diff',
#     'patch_url': 'https://github.com/tovade/Andoi/pull/9.patch',
#     'issue_url': 'https://api.github.com/repos/tovade/Andoi/issues/9',
#     'number': 9,
#     'state': 'open',
#     'locked': False,
#     'title': ':hammer: add dependabot config',
#     'user': {'login': 'tovade',
#      'id': 66245404,
#      'node_id': 'MDQ6VXNlcjY2MjQ1NDA0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tovade',
#      'html_url': 'https://github.com/tovade',
#      'followers_url': 'https://api.github.com/users/tovade/followers',
#      'following_url': 'https://api.github.com/users/tovade/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tovade/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tovade/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tovade/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tovade/orgs',
#      'repos_url': 'https://api.github.com/users/tovade/repos',
#      'events_url': 'https://api.github.com/users/tovade/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tovade/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2021-05-23T09:31:13Z',
#     'updated_at': '2021-05-23T09:31:13Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tovade/Andoi/pulls/9/commits',
#     'review_comments_url': 'https://api.github.com/repos/tovade/Andoi/pulls/9/comments',
#     'review_comment_url': 'https://api.github.com/repos/tovade/Andoi/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tovade/Andoi/issues/9/comments',
#     'statuses_url': 'https://api.github.com/repos/tovade/Andoi/statuses/cf2fd476d4ff157ca0f6df06c4120b59a4012096',
#     'head': {'label': 'tovade:development',
#      'ref': 'development',
#      'sha': 'cf2fd476d4ff157ca0f6df06c4120b59a4012096',
#      'user': {'login': 'tovade',
#       'id': 66245404,
#       'node_id': 'MDQ6VXNlcjY2MjQ1NDA0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tovade',
#       'html_url': 'https://github.com/tovade',
#       'followers_url': 'https://api.github.com/users/tovade/followers',
#       'following_url': 'https://api.github.com/users/tovade/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tovade/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tovade/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tovade/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tovade/orgs',
#       'repos_url': 'https://api.github.com/users/tovade/repos',
#       'events_url': 'https://api.github.com/users/tovade/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tovade/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 290533649,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA1MzM2NDk=',
#       'name': 'Andoi',
#       'full_name': 'tovade/Andoi',
#       'private': False,
#       'owner': {'login': 'tovade',
#        'id': 66245404,
#        'node_id': 'MDQ6VXNlcjY2MjQ1NDA0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tovade',
#        'html_url': 'https://github.com/tovade',
#        'followers_url': 'https://api.github.com/users/tovade/followers',
#        'following_url': 'https://api.github.com/users/tovade/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tovade/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tovade/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tovade/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tovade/orgs',
#        'repos_url': 'https://api.github.com/users/tovade/repos',
#        'events_url': 'https://api.github.com/users/tovade/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tovade/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tovade/Andoi',
#       'description': 'A bot coded by potatoexe2930 and tovade',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tovade/Andoi',
#       'forks_url': 'https://api.github.com/repos/tovade/Andoi/forks',
#       'keys_url': 'https://api.github.com/repos/tovade/Andoi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tovade/Andoi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tovade/Andoi/teams',
#       'hooks_url': 'https://api.github.com/repos/tovade/Andoi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tovade/Andoi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tovade/Andoi/events',
#       'assignees_url': 'https://api.github.com/repos/tovade/Andoi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tovade/Andoi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tovade/Andoi/tags',
#       'blobs_url': 'https://api.github.com/repos/tovade/Andoi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tovade/Andoi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tovade/Andoi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tovade/Andoi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tovade/Andoi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tovade/Andoi/languages',
#       'stargazers_url': 'https://api.github.com/repos/tovade/Andoi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tovade/Andoi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tovade/Andoi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tovade/Andoi/subscription',
#       'commits_url': 'https://api.github.com/repos/tovade/Andoi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tovade/Andoi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tovade/Andoi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tovade/Andoi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tovade/Andoi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tovade/Andoi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tovade/Andoi/merges',
#       'archive_url': 'https://api.github.com/repos/tovade/Andoi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tovade/Andoi/downloads',
#       'issues_url': 'https://api.github.com/repos/tovade/Andoi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tovade/Andoi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tovade/Andoi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tovade/Andoi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tovade/Andoi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tovade/Andoi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tovade/Andoi/deployments',
#       'created_at': '2020-08-26T15:25:24Z',
#       'updated_at': '2021-05-23T09:26:52Z',
#       'pushed_at': '2021-05-23T09:30:39Z',
#       'git_url': 'git://github.com/tovade/Andoi.git',
#       'ssh_url': 'git@github.com:tovade/Andoi.git',
#       'clone_url': 'https://github.com/tovade/Andoi.git',
#       'svn_url': 'https://github.com/tovade/Andoi',
#       'homepage': 'https://andoi.tk/',
#       'size': 4760,
#       'stargazers_count': 43,
#       'watchers_count': 43,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 16,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 16,
#       'open_issues': 1,
#       'watchers': 43,
#       'default_branch': 'master'}},
#     'base': {'label': 'tovade:master',
#      'ref': 'master',
#      'sha': '84ae0cac4d42235a0482a9a606d576c8206406d3',
#      'user': {'login': 'tovade',
#       'id': 66245404,
#       'node_id': 'MDQ6VXNlcjY2MjQ1NDA0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tovade',
#       'html_url': 'https://github.com/tovade',
#       'followers_url': 'https://api.github.com/users/tovade/followers',
#       'following_url': 'https://api.github.com/users/tovade/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tovade/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tovade/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tovade/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tovade/orgs',
#       'repos_url': 'https://api.github.com/users/tovade/repos',
#       'events_url': 'https://api.github.com/users/tovade/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tovade/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 290533649,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA1MzM2NDk=',
#       'name': 'Andoi',
#       'full_name': 'tovade/Andoi',
#       'private': False,
#       'owner': {'login': 'tovade',
#        'id': 66245404,
#        'node_id': 'MDQ6VXNlcjY2MjQ1NDA0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/66245404?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tovade',
#        'html_url': 'https://github.com/tovade',
#        'followers_url': 'https://api.github.com/users/tovade/followers',
#        'following_url': 'https://api.github.com/users/tovade/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tovade/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tovade/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tovade/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tovade/orgs',
#        'repos_url': 'https://api.github.com/users/tovade/repos',
#        'events_url': 'https://api.github.com/users/tovade/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tovade/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tovade/Andoi',
#       'description': 'A bot coded by potatoexe2930 and tovade',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tovade/Andoi',
#       'forks_url': 'https://api.github.com/repos/tovade/Andoi/forks',
#       'keys_url': 'https://api.github.com/repos/tovade/Andoi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tovade/Andoi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tovade/Andoi/teams',
#       'hooks_url': 'https://api.github.com/repos/tovade/Andoi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tovade/Andoi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tovade/Andoi/events',
#       'assignees_url': 'https://api.github.com/repos/tovade/Andoi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tovade/Andoi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tovade/Andoi/tags',
#       'blobs_url': 'https://api.github.com/repos/tovade/Andoi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tovade/Andoi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tovade/Andoi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tovade/Andoi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tovade/Andoi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tovade/Andoi/languages',
#       'stargazers_url': 'https://api.github.com/repos/tovade/Andoi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tovade/Andoi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tovade/Andoi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tovade/Andoi/subscription',
#       'commits_url': 'https://api.github.com/repos/tovade/Andoi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tovade/Andoi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tovade/Andoi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tovade/Andoi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tovade/Andoi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tovade/Andoi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tovade/Andoi/merges',
#       'archive_url': 'https://api.github.com/repos/tovade/Andoi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tovade/Andoi/downloads',
#       'issues_url': 'https://api.github.com/repos/tovade/Andoi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tovade/Andoi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tovade/Andoi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tovade/Andoi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tovade/Andoi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tovade/Andoi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tovade/Andoi/deployments',
#       'created_at': '2020-08-26T15:25:24Z',
#       'updated_at': '2021-05-23T09:26:52Z',
#       'pushed_at': '2021-05-23T09:30:39Z',
#       'git_url': 'git://github.com/tovade/Andoi.git',
#       'ssh_url': 'git@github.com:tovade/Andoi.git',
#       'clone_url': 'https://github.com/tovade/Andoi.git',
#       'svn_url': 'https://github.com/tovade/Andoi',
#       'homepage': 'https://andoi.tk/',
#       'size': 4760,
#       'stargazers_count': 43,
#       'watchers_count': 43,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 16,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 16,
#       'open_issues': 1,
#       'watchers': 43,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tovade/Andoi/pulls/9'},
#      'html': {'href': 'https://github.com/tovade/Andoi/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/tovade/Andoi/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/tovade/Andoi/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tovade/Andoi/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tovade/Andoi/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tovade/Andoi/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tovade/Andoi/statuses/cf2fd476d4ff157ca0f6df06c4120b59a4012096'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 4,
#     'additions': 278,
#     'deletions': 378,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364561',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 370011109,
#    'name': 'codestar-github-bot-1/user-public-seeded-repo-eu-central-1',
#    'url': 'https://api.github.com/repos/codestar-github-bot-1/user-public-seeded-repo-eu-central-1'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Seeded Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364552',
#   'type': 'PushEvent',
#   'actor': {'id': 72582311,
#    'login': 'mabraha2',
#    'display_login': 'mabraha2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mabraha2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72582311?'},
#   'repo': {'id': 302478573,
#    'name': 'mabraha2/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/mabraha2/learn-co-sandbox'},
#   'payload': {'push_id': 7172327188,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '0834c5e85d7f70dcfa437a95e1b7fd4e66fd4f6c',
#    'before': 'ef03c0994aeed0fc4b97435344946632926c5094',
#    'commits': [{'sha': '0834c5e85d7f70dcfa437a95e1b7fd4e66fd4f6c',
#      'author': {'email': 'abrahama2019@gmail.com', 'name': 'Medhanei  Abraha'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mabraha2/learn-co-sandbox/commits/0834c5e85d7f70dcfa437a95e1b7fd4e66fd4f6c'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364538',
#   'type': 'PushEvent',
#   'actor': {'id': 6992947,
#    'login': 'brentyi',
#    'display_login': 'brentyi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brentyi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6992947?'},
#   'repo': {'id': 313247352,
#    'name': 'brentyi/jaxfg',
#    'url': 'https://api.github.com/repos/brentyi/jaxfg'},
#   'payload': {'push_id': 7172327186,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0efa72c7de495b2c9ef76a70c73ba999f300ecc8',
#    'before': '9a3c7724567ffc6fb5344ee582c3e237ca03591d',
#    'commits': [{'sha': '0efa72c7de495b2c9ef76a70c73ba999f300ecc8',
#      'author': {'email': 'yibrenth@gmail.com', 'name': 'Brent Yi'},
#      'message': 'Nonlinear optimizer refactor\n- Make solves transform-friendly: LAX loop constructs; host callbacks\n  for diagnostics\n- Reduce redundant code\n- As a side effect, improves dogleg performance on m3500 (...why?)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brentyi/jaxfg/commits/0efa72c7de495b2c9ef76a70c73ba999f300ecc8'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:13Z'},
#  {'id': '16470364550',
#   'type': 'PushEvent',
#   'actor': {'id': 57421193,
#    'login': 'joshua-simon',
#    'display_login': 'joshua-simon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joshua-simon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57421193?'},
#   'repo': {'id': 354684051,
#    'name': 'joshua-simon/react-context-app',
#    'url': 'https://api.github.com/repos/joshua-simon/react-context-app'},
#   'payload': {'push_id': 7172327193,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e472398eb0a6261597b078799ff558d261790944',
#    'before': '3ddb9ac4386c15206bd58e7d353169843e457f3d',
#    'commits': [{'sha': 'e472398eb0a6261597b078799ff558d261790944',
# ...
#     {'sha': '18507ae7c59105f30d5e2f95a351613114ab28d4',
#      'author': {'email': 'ma15fo43@gmail.com', 'name': 'Mazz'},
#      'message': 'Merge pull request #268 from mazzlabs/depfu/update/npm/@types/node-15.6.0\n\nUpdate @types/node: 15.3.1 → 15.6.0 (minor)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mazzlabs/Mango/commits/18507ae7c59105f30d5e2f95a351613114ab28d4'},
#     {'sha': '62da230c7368fcfe4721ebe1d2cbf6a9195548dd',
#      'author': {'email': '23717796+depfu[bot]@users.noreply.github.com',
#       'name': 'depfu[bot]'},
#      'message': '🎈 chore(package): update dotenv to version 10.0.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mazzlabs/Mango/commits/62da230c7368fcfe4721ebe1d2cbf6a9195548dd'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z'},
#  {'id': '16470364504',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 19358114,
#    'name': 'night/betterttv',
#    'url': 'https://api.github.com/repos/night/betterttv'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/night/betterttv/issues/1732',
#     'repository_url': 'https://api.github.com/repos/night/betterttv',
#     'labels_url': 'https://api.github.com/repos/night/betterttv/issues/1732/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/night/betterttv/issues/1732/comments',
#     'events_url': 'https://api.github.com/repos/night/betterttv/issues/1732/events',
#     'html_url': 'https://github.com/night/betterttv/pull/1732',
#     'id': 187523233,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0OTI0NjczMjY=',
#     'number': 1732,
#     'title': 'Nov 5 fixes',
#     'user': {'login': 'EhsanKia',
#      'id': 1619970,
#      'node_id': 'MDQ6VXNlcjE2MTk5NzA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1619970?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/EhsanKia',
#      'html_url': 'https://github.com/EhsanKia',
#      'followers_url': 'https://api.github.com/users/EhsanKia/followers',
#      'following_url': 'https://api.github.com/users/EhsanKia/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/EhsanKia/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/EhsanKia/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/EhsanKia/subscriptions',
#      'organizations_url': 'https://api.github.com/users/EhsanKia/orgs',
#      'repos_url': 'https://api.github.com/users/EhsanKia/repos',
#      'events_url': 'https://api.github.com/users/EhsanKia/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/EhsanKia/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2016-11-05T21:07:49Z',
#     'updated_at': '2021-05-23T09:31:12Z',
#     'closed_at': '2016-11-05T22:05:19Z',
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/night/betterttv/pulls/1732',
#      'html_url': 'https://github.com/night/betterttv/pull/1732',
#      'diff_url': 'https://github.com/night/betterttv/pull/1732.diff',
#      'patch_url': 'https://github.com/night/betterttv/pull/1732.patch'},
#     'body': "Bunch of fixes:\r\n\r\n- Change BVL button selector to work for all languages #1713 \r\n- Make dark theme work on frontpage again #1730 \r\n- Don't force scroll chat on key up #1710 \r\n- Refactor whisper message parsing to hopefully fix #1728 \r\n- Fix sub badges once again...",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/night/betterttv/issues/comments/846532868',
#     'html_url': 'https://github.com/night/betterttv/pull/1732#issuecomment-846532868',
#     'issue_url': 'https://api.github.com/repos/night/betterttv/issues/1732',
#     'id': 846532868,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDg0NjUzMjg2OA==',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-05-23T09:31:12Z',
#     'updated_at': '2021-05-23T09:31:12Z',
#     'author_association': 'NONE',
#     'body': 'This pull request has been automatically locked since there has not been any recent activity after it was closed. Please open a new pull request for related issues or feature requests.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z'},
#  {'id': '16470364509',
#   'type': 'WatchEvent',
#   'actor': {'id': 81124817,
#    'login': 'A469L372K397',
#    'display_login': 'A469L372K397',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/A469L372K397',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81124817?'},
#   'repo': {'id': 266970592,
#    'name': 'FioraLove/Net-Spider',
#    'url': 'https://api.github.com/repos/FioraLove/Net-Spider'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z'},
#  {'id': '16470364505',
#   'type': 'PushEvent',
#   'actor': {'id': 23217274,
#    'login': 'thatsparrow',
#    'display_login': 'thatsparrow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thatsparrow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23217274?'},
#   'repo': {'id': 118468922,
#    'name': 'OSIRISagency/OSIRISagency.github.io',
#    'url': 'https://api.github.com/repos/OSIRISagency/OSIRISagency.github.io'},
#   'payload': {'push_id': 7172327164,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '243e048fb486a84e4adb408eb66a5969120e03c6',
#    'before': '830ec2dff9b77fd83415046a568fba9b3ec6b47f',
#    'commits': [{'sha': '243e048fb486a84e4adb408eb66a5969120e03c6',
#      'author': {'email': 'jbenjamin001@gmail.com', 'name': 'Jann'},
#      'message': 'Delete CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OSIRISagency/OSIRISagency.github.io/commits/243e048fb486a84e4adb408eb66a5969120e03c6'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z',
#   'org': {'id': 29859078,
#    'login': 'OSIRISagency',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OSIRISagency',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29859078?'}},
#  {'id': '16470364508',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 37936606,
#    'login': 'github-learning-lab[bot]',
#    'display_login': 'github-learning-lab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-learning-lab[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37936606?'},
#   'repo': {'id': 369987890,
#    'name': 'mehrotra-prateek/github-actions-for-ci',
#    'url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/5',
#     'repository_url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci',
#     'labels_url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/5/events',
#     'html_url': 'https://github.com/mehrotra-prateek/github-actions-for-ci/pull/5',
#     'id': 898974946,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjUwNzU1MDIx',
#     'number': 5,
#     'title': 'Improve CI',
#     'user': {'login': 'mehrotra-prateek',
#      'id': 10025611,
#      'node_id': 'MDQ6VXNlcjEwMDI1NjEx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10025611?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mehrotra-prateek',
#      'html_url': 'https://github.com/mehrotra-prateek',
#      'followers_url': 'https://api.github.com/users/mehrotra-prateek/followers',
#      'following_url': 'https://api.github.com/users/mehrotra-prateek/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mehrotra-prateek/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mehrotra-prateek/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mehrotra-prateek/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mehrotra-prateek/orgs',
#      'repos_url': 'https://api.github.com/users/mehrotra-prateek/repos',
#      'events_url': 'https://api.github.com/users/mehrotra-prateek/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mehrotra-prateek/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2021-05-23T09:16:57Z',
#     'updated_at': '2021-05-23T09:31:12Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/pulls/5',
#      'html_url': 'https://github.com/mehrotra-prateek/github-actions-for-ci/pull/5',
#      'diff_url': 'https://github.com/mehrotra-prateek/github-actions-for-ci/pull/5.diff',
#      'patch_url': 'https://github.com/mehrotra-prateek/github-actions-for-ci/pull/5.patch'},
#     'body': '',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/comments/846532867',
#     'html_url': 'https://github.com/mehrotra-prateek/github-actions-for-ci/pull/5#issuecomment-846532867',
#     'issue_url': 'https://api.github.com/repos/mehrotra-prateek/github-actions-for-ci/issues/5',
#     'id': 846532867,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDg0NjUzMjg2Nw==',
#     'user': {'login': 'github-learning-lab[bot]',
#      'id': 37936606,
#      'node_id': 'MDM6Qm90Mzc5MzY2MDY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/10572?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-learning-lab',
#      'followers_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-05-23T09:31:12Z',
#     'updated_at': '2021-05-23T09:31:12Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '# Use the upload\n\nThe workflow has finished running!\n\nYou may notice `build` succeeded, but each of the `test` jobs failed. That\'s because the build artifacts created in `build` aren\'t available to the `test` job. Each job executes in a fresh instance of the virtual environment. This is due to the [design of the virtual environments](https://help.github.com/en/articles/virtual-environments-for-github-actions#about-virtual-environments) themselves.\n\nSo what do we do when we need the work product of one job in another? We can use the built-in [artifact storage](https://help.github.com/en/articles/persisting-workflow-data-using-artifacts) to save artifacts created from one job to be used in another job within the same workflow. \n\n## Step 11: Upload a job\'s build artifacts\n\n<img alt="icon of a binary file" align="left" width="100" height="100" src="https://user-images.githubusercontent.com/6351798/88592731-b2c26480-d01b-11ea-850e-c87588aadf4f.png">\n\nArtifacts allow you to persist data after a job has completed, and share that data with another job in the same workflow. An artifact is a file or collection of files produced during a workflow run.\n\nTo upload artifacts to the artifact storage, we can use an action built by GitHub: [`actions/upload-artifacts`](https://github.com/actions/upload-artifact).\n\n### :keyboard: Activity: Use the upload action in your workflow file to save a job\'s build artifacts\n\n_You can follow the manual steps below, or accept the suggestion in the following comment._\n\n1. Edit [your workflow file](https://github.com/mehrotra-prateek/github-actions-for-ci/edit/mehrotra-prateek-patch-1/.github/workflows/node.js.yml?pr=/mehrotra-prateek/github-actions-for-ci/pull/5)\n1. Add a step to your `build` job that uses the `upload-artifacts` action.\n    ```yaml\n      build:\n        runs-on: ubuntu-latest\n        steps:\n          - uses: actions/checkout@v2\n          - name: npm install and build webpack\n            run: |\n              npm install\n              npm run build\n          - uses: actions/upload-artifact@main\n            with:\n              name: webpack artifacts\n              path: public/\n    ```\n1. Commit your change to this branch\n\nI\'ll respond when you commit to this branch.\n',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z'},
#  {'id': '16470364499',
#   'type': 'PushEvent',
#   'actor': {'id': 61057625,
#    'login': 'ShadowWhisperer',
#    'display_login': 'ShadowWhisperer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShadowWhisperer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61057625?'},
#   'repo': {'id': 366885169,
#    'name': 'ShadowWhisperer/IPs',
#    'url': 'https://api.github.com/repos/ShadowWhisperer/IPs'},
#   'payload': {'push_id': 7172327158,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b589cc63af7d84b5e60cd8b88731d94423415c28',
#    'before': '48ee7200324e08ef12e01891a313f8e6aece9f7a',
#    'commits': [{'sha': 'b589cc63af7d84b5e60cd8b88731d94423415c28',
#      'author': {'email': 'heibult@gmail.com', 'name': 'ShadowWhisperer'},
#      'message': 'Automated Upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ShadowWhisperer/IPs/commits/b589cc63af7d84b5e60cd8b88731d94423415c28'}]},
#   'public': True,
#   'created_at': '2021-05-23T09:31:12Z'}]

# %%
# 差異
# r.text主要輸出字串格式，json.loads(r.text)輸出list 加上 dictionary格式

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
URL = 'https://cat-fact.herokuapp.com/facts'
resp = requests.get(url=URL)

# %%
json.loads(resp.text)
# 傳回內容主要json格式，可運用Dataframes進行資料輸出
# Out:
# [{'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e008800aac31001185ed07',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-06T21:20:03.505Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e008630aac31001185ed01',
#   'user': '58e007480aac31001185ecef',
#   'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-02-07T21:20:02.903Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e00a090aac31001185ed16',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-02-11T21:20:03.745Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e009390aac31001185ed10',
#   'user': '58e007480aac31001185ecef',
#   'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-04T21:20:02.979Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e008780aac31001185ed05',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-29T20:20:03.844Z',
#   'used': False}]

# %%
import pandas as pd

# %%
pd.DataFrame(json.loads(resp.text))
# Out:
#                                status type  deleted                       _id  \
# 0  {'verified': True, 'sentCount': 1}  cat    False  58e008800aac31001185ed07
# 1  {'verified': True, 'sentCount': 1}  cat    False  58e008630aac31001185ed01
# 2  {'verified': True, 'sentCount': 1}  cat    False  58e00a090aac31001185ed16
# 3  {'verified': True, 'sentCount': 1}  cat    False  58e009390aac31001185ed10
# 4  {'verified': True, 'sentCount': 1}  cat    False  58e008780aac31001185ed05
#
#                        user  \
# 0  58e007480aac31001185ecef
# 1  58e007480aac31001185ecef
# 2  58e007480aac31001185ecef
# 3  58e007480aac31001185ecef
# 4  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Wikipedia has a recording of a cat meowing, be...    0   user
# 1  When cats grimace, they are usually "taste-sce...    0   user
# 2  Cats make more than 100 different sounds where...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  Owning a cat can reduce the risk of stroke and...    0   user
#
#                   updatedAt                 createdAt   used
# 0  2020-08-23T20:20:01.611Z  2018-03-06T21:20:03.505Z  False
# 1  2020-08-23T20:20:01.611Z  2018-02-07T21:20:02.903Z  False
# 2  2020-08-23T20:20:01.611Z  2018-02-11T21:20:03.745Z  False
# 3  2020-08-23T20:20:01.611Z  2018-03-04T21:20:02.979Z  False
# 4  2020-08-23T20:20:01.611Z  2018-03-29T20:20:03.844Z  False
